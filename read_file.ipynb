# %%
import pandas as pd
import numpy as np

# %%
io='.\data\Price & Premium rate.xlsx'

price_data=pd.read_excel(io,sheet_name=1,header=[0,1])

# %%
price_data
# Out:
#            100009.SH 125898.SZ 100220.SH 125002.SZ 100087.SH 126301.SZ  \
#             机场转债(退市)  鞍钢转债(退市)  阳光转债(退市)  万科转债(退市)  水运转债(退市)  丝绸转2(退市)
# 2015-01-05         0         0         0         0         0         0
# 2015-01-06         0         0         0         0         0         0
# 2015-01-07         0         0         0         0         0         0
# 2015-01-08         0         0         0         0         0         0
# 2015-01-09         0         0         0         0         0         0
# 2015-01-12         0         0         0         0         0         0
# 2015-01-13         0         0         0         0         0         0
# 2015-01-14         0         0         0         0         0         0
# 2015-01-15         0         0         0         0         0         0
# 2015-01-16         0         0         0         0         0         0
# 2015-01-19         0         0         0         0         0         0
# ...

# %%
one_bond=price_data.iloc[:,1]

# %%
one_bond
# Out:
# 2015-01-05    0
# 2015-01-06    0
# 2015-01-07    0
# 2015-01-08    0
# 2015-01-09    0
# 2015-01-12    0
# 2015-01-13    0
# 2015-01-14    0
# 2015-01-15    0
# 2015-01-16    0
# 2015-01-19    0
# 2015-01-20    0
# 2015-01-21    0
# 2015-01-22    0
# 2015-01-23    0
# 2015-01-26    0
# 2015-01-27    0
# 2015-01-28    0
# 2015-01-29    0
# 2015-01-30    0
# 2015-02-02    0
# 2015-02-03    0
# 2015-02-04    0
# 2015-02-05    0
# 2015-02-06    0
# 2015-02-09    0
# 2015-02-10    0
# 2015-02-11    0
# 2015-02-12    0
# 2015-02-13    0
#              ..
# 2019-12-20    0
# 2019-12-23    0
# 2019-12-24    0
# 2019-12-25    0
# 2019-12-26    0
# 2019-12-27    0
# 2019-12-30    0
# 2019-12-31    0
# 2020-01-02    0
# 2020-01-03    0
# 2020-01-06    0
# 2020-01-07    0
# 2020-01-08    0
# 2020-01-09    0
# 2020-01-10    0
# 2020-01-13    0
# 2020-01-14    0
# 2020-01-15    0
# 2020-01-16    0
# 2020-01-17    0
# 2020-01-20    0
# 2020-01-21    0
# 2020-01-22    0
# 2020-01-23    0
# ...

# %%
price_data.duplicated()
# Out:
# 2015-01-05    False
# 2015-01-06    False
# 2015-01-07    False
# 2015-01-08    False
# 2015-01-09    False
# 2015-01-12    False
# 2015-01-13    False
# 2015-01-14    False
# 2015-01-15    False
# 2015-01-16    False
# 2015-01-19    False
# 2015-01-20    False
# 2015-01-21    False
# 2015-01-22    False
# 2015-01-23    False
# 2015-01-26    False
# 2015-01-27    False
# 2015-01-28    False
# 2015-01-29    False
# 2015-01-30    False
# 2015-02-02    False
# 2015-02-03    False
# 2015-02-04    False
# 2015-02-05    False
# 2015-02-06    False
# 2015-02-09    False
# 2015-02-10    False
# 2015-02-11    False
# 2015-02-12    False
# 2015-02-13    False
#               ...
# 2019-12-20    False
# 2019-12-23    False
# 2019-12-24    False
# 2019-12-25    False
# 2019-12-26    False
# 2019-12-27    False
# 2019-12-30    False
# 2019-12-31    False
# 2020-01-02    False
# 2020-01-03    False
# 2020-01-06    False
# 2020-01-07    False
# 2020-01-08    False
# 2020-01-09    False
# ...

# %%
zero_bond=pd.DataFrame(np.zeros(price_data.iloc[:,0].count(),1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-dde5e86d38bc> in <module>
# ----> 1 zero_bond=pd.DataFrame(np.zeros(price_data.iloc[:,0].count(),1))
#
# TypeError: data type not understood
